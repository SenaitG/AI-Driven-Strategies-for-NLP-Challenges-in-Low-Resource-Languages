# %%
import pandas as pd
df = pd.read_csv (r'semval3class/third_set6000.csv')
display(df)
# Out:
#                                                sequence     score      labels  \
# 0     dear the newOoffice for Mac is great and all b...  0.898246       grief
# 1     how about you make a system that doesnt eat my...  0.960672      horror
# 2     I may be ignorant on this issue but should we ...  0.594435        hope
# 3             Thanks to I just may be switching over to  0.916901        hope
# 4     If I make a game as a windows10 Universal App ...  0.860276        hope
# ...                                                 ...       ...         ...
# 5995  ok good to know Punting at MetLife in December...  0.968778        hope
# 5996  everyone who sat around me at metlife was so a...  0.308079    pleasure
# 5997  what giants or niners fans would wanna go to t...  0.092980    pleasure
# 5998  Anybody want a ticket for tomorrow Colombia vs...  0.617128        hope
# 5999  Mendez told me hed drive me to MetLife on Sund...  0.936189  generosity
#
#      real_class
# ...

# %%
sentence = []
for x in df.sequence:
    sentence.append(x)

clas = []
for y in df.real_class:
    clas.append(y)
print(len(clas))
print(clas)
# Out:
# 6000
# ...

# %%
import numpy as np 
import pandas as pd
from sentence_transformers import SentenceTransformer
import torch 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import seaborn as sns
model = SentenceTransformer('sentence-transformers/LaBSE')

# %%
embeddings = model.encode(sentence, batch_size = 128, convert_to_numpy = True, show_progress_bar = True)
# Out:
# Batches:   0%|          | 0/47 [00:00<?, ?it/s]

# %%
from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
label_encoder = LabelEncoder()
label_encoder.fit(clas)
y_a = label_encoder.transform(clas)
print(y_a)
# Out:
# [0 0 0 ... 1 2 1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
     embeddings, y_a, stratify=y_a, random_state=42)

# %%
from keras.models import Sequential
from keras import layers

input_dim = embeddings.shape[1]
model = Sequential()
model.add(layers.Dense(64, input_dim =input_dim, activation = 'relu'))
model.add(layers.Dense(1, activation ='sigmoid'))
model.compile(loss='binary_crossentropy',
             optimizer ='adam',
             metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 64)                49216
#
#  dense_3 (Dense)             (None, 1)                 65
#
# ...
# Total params: 49,281
# Trainable params: 49,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist =model.fit(X_train, y_train, epochs = 100, batch_size = 128, verbose = 1)
# Out:
# Epoch 1/100
# 36/36 [==============================] - 1s 1ms/step - loss: -0.0148 - accuracy: 0.3364
# Epoch 2/100
# 36/36 [==============================] - 0s 3ms/step - loss: -1.3870 - accuracy: 0.3404
# Epoch 3/100
# 36/36 [==============================] - 0s 3ms/step - loss: -2.9118 - accuracy: 0.3404
# Epoch 4/100
# 36/36 [==============================] - 0s 4ms/step - loss: -5.0663 - accuracy: 0.3404
# Epoch 5/100
# 36/36 [==============================] - 0s 3ms/step - loss: -7.9930 - accuracy: 0.3404
# Epoch 6/100
# 36/36 [==============================] - 0s 3ms/step - loss: -11.7306 - accuracy: 0.3404
# Epoch 7/100
# 36/36 [==============================] - 0s 3ms/step - loss: -16.3355 - accuracy: 0.3404
# Epoch 8/100
# 36/36 [==============================] - 0s 3ms/step - loss: -21.7708 - accuracy: 0.3404
# Epoch 9/100
# 36/36 [==============================] - 0s 3ms/step - loss: -28.0286 - accuracy: 0.3404
# Epoch 10/100
# ...

# %%
score,acc  = model.evaluate(X_test, y_test, verbose=1)
print('Test accuracy:', acc)
# Out:
# 47/47 [==============================] - 0s 2ms/step - loss: -3227.7407 - accuracy: 0.3407
# Test accuracy: 0.34066668152809143
